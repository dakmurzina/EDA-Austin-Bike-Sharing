# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 2.8 MB/s ta 0:00:011
# Requirement already satisfied: requests in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from folium) (2.26.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from folium) (1.24.2)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vjfychan/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.2)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from geopy.geocoders import ArcGIS
import folium

# %%
bike_df = pd.read_csv('bikeshare_stations.csv')
bike_df.head()
# Out:
#    station_id                             name  status             address  \
# 0        2541  State Capitol @ 14th & Colorado  closed     206 W. 14th St.
# 1        2538  Bullock Museum @ Congress & MLK  closed  1881 Congress Ave.
# 2        2545          ACC - Rio Grande & 12th  closed     700 W. 12th St.
# 3        2546         ACC - West & 12th Street  closed      1231 West Ave.
# 4        2564                 5th & San Marcos  closed        991 East 5th
#
#   alternate_name  city_asset_number property_type  number_of_docks power_type  \
# 0            NaN                NaN           NaN              NaN        NaN
# 1            NaN                NaN           NaN              NaN        NaN
# 2            NaN                NaN           NaN              NaN        NaN
# 3            NaN                NaN           NaN              NaN        NaN
# 4            NaN                NaN           NaN              NaN        NaN
#
#    footprint_length  footprint_width notes  council_district  \
# 0               NaN              NaN   NaN                 1
# 1               NaN              NaN   NaN                 1
# 2               NaN              NaN   NaN                 9
# 3               NaN              NaN   NaN                 9
# 4               NaN              NaN   NaN                 3
#
#                     modified_date
# 0  2021-01-04 12:00:00.000000 UTC
# 1  2021-01-04 12:00:00.000000 UTC
# 2  2021-01-04 12:00:00.000000 UTC
# 3  2021-01-04 12:00:00.000000 UTC
# 4  2021-01-04 12:00:00.000000 UTC

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   station_id         102 non-null    int64
#  1   name               102 non-null    object
#  2   status             102 non-null    object
#  3   address            101 non-null    object
#  4   alternate_name     2 non-null      object
#  5   city_asset_number  77 non-null     float64
#  6   property_type      84 non-null     object
#  7   number_of_docks    82 non-null     float64
#  8   power_type         84 non-null     object
#  9   footprint_length   79 non-null     float64
#  10  footprint_width    79 non-null     float64
#  11  notes              32 non-null     object
#  12  council_district   102 non-null    int64
#  13  modified_date      102 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 11.3+ KB

# %% [markdown]
# ### Pre-processing of string data types:
# - Removal of leading and trailing whitespaces
# - Removal of punctuaton in address column
# - Standardisation of address, for eg "St" vs "Street", "E" vs "East"
# - Some entries are not actually addresses

# %%
# remove trailing and leading whitespaces
strip_spaces = lambda x: x.str.strip()
bike_df[['name', 'status','address','notes']] = bike_df[['name', 'status','address','notes']].apply(strip_spaces)

# %%
# remove punctuation in address column
bike_df['address'] = bike_df['address'].str.replace('.', '', regex=True) #not word or not space

# %%
# Some addresses are invalid. Let's replace these with the station name
bike_df[bike_df['address'].str.contains('Presented')]
# Out:
#     station_id                                 name  status  \
# 23        2575                 Riverside @ S. Lamar  active
# 34        2503               South Congress & James  active
# 48        2549  Long Center @ South 1st & Riverside  active
# 53        2566        Pfluger Bridge @ W 2nd Street  active
# 54        2499             City Hall / Lavaca & 2nd  active
# 72        2501                          5th & Bowie  active
#
#                                          address alternate_name  \
# 23          Presented by Austin Parks Foundation            NaN
# 34             Presented by The Austin Chronicle            NaN
# 48                    Presented by Austin Energy            NaN
# 53          Presented by Austin Parks Foundation            NaN
# 54  Presented by Graves Dougherty Hearon & Moody            NaN
# 72               Presented by Whole Foods Market            NaN
#
#     city_asset_number property_type  number_of_docks power_type  \
# 23            16736.0      parkland             15.0      solar
# 34            16730.0      sidewalk              9.0      solar
# 48            16750.0      sidewalk             13.0      solar
# 53            16762.0      sidewalk             19.0      solar
# 54            16732.0      sidewalk             19.0      solar
# 72            16728.0  paid_parking             15.0      solar
#
#     footprint_length  footprint_width                     notes  \
# 23              45.0              5.0  parkland at ROW/easement
# 34              26.0              7.5               on bulb-out
# 48              40.0              5.0                       NaN
# 53              55.0              5.0      adjacent to parkland
# 54              55.0              5.0          check dock #-18?
# 72              45.0              5.0                       NaN
#
#     council_district                   modified_date
# 23                 5  2021-01-04 12:00:00.000000 UTC
# 34                 9  2021-01-04 12:00:00.000000 UTC
# 48                 9  2021-01-04 12:00:00.000000 UTC
# 53                 9  2021-01-04 12:00:00.000000 UTC
# 54                 9  2021-01-04 12:00:00.000000 UTC
# 72                 9  2021-01-04 12:00:00.000000 UTC

# %%
# Find rows where address is incorrect and replace with bike station name
bike_df.loc[bike_df['address'].str.contains('Presented'), 'address'] = bike_df['name']

# %%
# Fill null values in address column with bike station name
bike_df["address"] = bike_df["address"].fillna(bike_df["name"])

# %%
# Standardise address, for eg. "Road" is replaced by "Rd" 

words_dict = {'Street' : 'St', 'Avenue' : 'Ave', 'Road':'Rd', 
              'Drive': 'Dr', 'Boulevard' : 'Blvd', 'North' : 'N', 
              'South' : 'S', 'East' : 'E', 'West': 'W'}

# get(key, value)
bike_df['address'] = bike_df['address'].apply(lambda x: ' '.join([words_dict.get(i, i) for i in x.split()]))

# %% [markdown]
# ## Locate longitude and latitude of the bike stations
# Using ArcGIS, a web-based mapping software, we can input the given address of the bike stations from the dataset and get the full address, longtitude and latitude.
# With this information, we can create visuals to see location of bike stations and journeys taken by bike riders.
#
# We will create three new columns:
# - full_adresss
# - longitude
# - latitude
#
# Not all the addresses generated were accurate so these had to be changed manually.

# %%
#Add 'Austin Texas' to give more information
bike_df['address'] = bike_df['address'] + ' Austin Texas'

# %%
# Initiate ArcGIS a
nom = ArcGIS()

# %%
# Create column that gets address, latitude and longitude
bike_df['coordinates']=bike_df['address'].apply(nom.geocode)

#extract coordinates and store it in lat and lon columns
bike_df['full_address']=bike_df['coordinates'].apply(lambda x:x.address)
bike_df['lat']=bike_df['coordinates'].apply(lambda x:x.latitude)
bike_df['lon']=bike_df['coordinates'].apply(lambda x:x.longitude)

# %%
# Not all rows were successfully matched, find rows where location was not found to be Austin and change manually
# station_id 2546, 2566, 2537 are incorrect.

bike_df[~bike_df['full_address'].str.contains('Austin')]
# Out:
#     station_id                               name  status  \
# 3         2546           ACC - West & 12th Street  closed
# 39        2550    4th/Guadalupe @ Republic Square  active
# 43        3455  Republic Square @ 5th & Guadalupe  closed
# 53        2566      Pfluger Bridge @ W 2nd Street  active
# 91        2537                     West & 6th St.  active
#
#                                          address alternate_name  \
# 3                        1231 W Ave Austin Texas            NaN
# 39  4th/Guadalupe @ Republic Square Austin Texas            NaN
# 43         Federal Courthouse Plaza Austin Texas            NaN
# 53        Pfluger Bridge @ W 2nd St Austin Texas            NaN
# 91                        603 W Ave Austin Texas            NaN
#
#     city_asset_number         property_type  number_of_docks   power_type  \
# 3                 NaN                   NaN              NaN          NaN
# 39                NaN              sidewalk             17.0        solar
# 43            16741.0              sidewalk             13.0  non-metered
# 53            16762.0              sidewalk             19.0        solar
# 91            16737.0  undetermined_parking             13.0        solar
#
#     footprint_length  footprint_width                        notes  \
# 3                NaN              NaN                          NaN
# 39              30.0              5.0                          NaN
# 43              40.0              5.0  Moved back to 4th/Guadalupe
# 53              55.0              5.0         adjacent to parkland
# 91              40.0              5.0                          NaN
#
#     council_district                   modified_date  \
# 3                  9  2021-01-04 12:00:00.000000 UTC
# 39                 9  2022-03-04 10:28:00.000000 UTC
# 43                 9  2022-03-04 10:24:00.000000 UTC
# 53                 9  2021-01-04 12:00:00.000000 UTC
# 91                 9  2021-01-04 12:00:00.000000 UTC
#
#                                           coordinates  \
# 3   (1231 S Ave A St, Bellville, Texas, 77418, (29...
# 39  (Republic Square Park, (30.267720000000054, -9...
# 43  (Federal Courthouse, (30.268820000000062, -97....
# 53  (Pfluger St W & S 2nd St, Pflugerville, Texas,...
# 91  (603 S Ave A St, Bellville, Texas, 77418, (29....
#
#                                          full_address        lat        lon
# 3            1231 S Ave A St, Bellville, Texas, 77418  29.936565 -96.249771
# 39                               Republic Square Park  30.267720 -97.746820
# 43                                 Federal Courthouse  30.268820 -97.744170
# 53  Pfluger St W & S 2nd St, Pflugerville, Texas, ...  30.438780 -97.622870
# 91            603 S Ave A St, Bellville, Texas, 77418  29.938709 -96.248655

# %%
# Manually change data for station_id 2546, 2566, 2537 based on long and lat on Google Maps
bike_df.loc[bike_df['station_id'] == 2546, ['full_address', 'lat', 'lon']]  = ['1231 W Ave, Austin, Texas, 78701', 30.276460, -97.748220]

bike_df.loc[bike_df['station_id'] == 2566, ['full_address', 'lat', 'lon']]  = ['W 2nd St, Austin, Texas, 78701', 30.264320, -97.744490]

bike_df.loc[bike_df['station_id'] == 2537, ['full_address', 'lat', 'lon']]  = ['603 W Ave, Austin, Texas, 78701', 30.270678, -97.750389]

# %%
bike_df.columns

# need to drop irrelavant columns
# Out:
# Index(['station_id', 'name', 'status', 'address', 'alternate_name',
#        'city_asset_number', 'property_type', 'number_of_docks', 'power_type',
#        'footprint_length', 'footprint_width', 'notes', 'council_district',
#        'modified_date', 'coordinates', 'full_address', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# ## Bike station locations
# Now we can plot the locations of all the bike stations on a map

# %%
map_new=folium.Map(width=1200, height=400,zoom_start=20)
list_coor=bike_df[['full_address','lat','lon']].values.tolist()
for i in list_coor:
    map_new.add_child(folium.Marker(location=[i[1],i[2]],
                                popup=i[0],icon=folium.Icon(color='green')))
    
sw = bike_df[['lat', 'lon']].min().values.tolist()
ne = bike_df[['lat', 'lon']].max().values.tolist()

map_new.fit_bounds([sw, ne]) 

map_new
# map_new.save('bike station.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecb00038b8e5a33f9e2c45a2e74b189f {
#                     position: relative;
#                     width: 1200.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecb00038b8e5a33f9e2c45a2e74b189f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecb00038b8e5a33f9e2c45a2e74b189f = L.map(
#                 &quot;map_ecb00038b8e5a33f9e2c45a2e74b189f&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aacbc86318dc82f259ddae9b61c1cd5b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ecb00038b8e5a33f9e2c45a2e74b189f);
#
#
#             var marker_b773bdada66f49763c2a87fec4b17da5 = L.marker(
#                 [30.276798005344716, -97.7416930337165],
#                 {}
#             ).addTo(map_ecb00038b8e5a33f9e2c45a2e74b189f);
#
#
#             var icon_018b37f92389d9a14139d2491b2c913d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b773bdada66f49763c2a87fec4b17da5.setIcon(icon_018b37f92389d9a14139d2491b2c913d);
#
#
#         var popup_81ea0ad0b04fbad2498c40cd56c32028 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24b6f78d05d378063c628de14e8e641d = $(`&lt;div id=&quot;html_24b6f78d05d378063c628de14e8e641d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;206 W 14th St, Austin, Texas, 78701&lt;/div&gt;`)[0];
#                 popup_81ea0ad0b04fbad2498c40cd56c32028.setContent(html_24b6f78d05d378063c628de14e8e641d);
#
#
#
#         marker_b773bdada66f49763c2a87fec4b17da5.bindPopup(popup_81ea0ad0b04fbad2498c40cd56c32028)
#         ;
#
#
#
#
#             var marker_364d8c775bd5df7ae53b7d36669871a7 = L.marker(
#                 [30.2805243534217, -97.73809687174912],
#                 {}
#             ).addTo(map_ecb00038b8e5a33f9e2c45a2e74b189f);
#
#
#             var icon_f3c8df05987fa058e174d168a6f6660c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_364d8c775bd5df7ae53b7d36669871a7.setIcon(icon_f3c8df05987fa058e174d168a6f6660c);
#
#
#         var popup_c5f60941c3d8d13100cdb3f819d64857 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb802bb3630e9f1d1d50c2442c89e482 = $(`&lt;div id=&quot;html_eb802bb3630e9f1d1d50c2442c89e482&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1881 Congress Ave, Austin, Texas, 78701&lt;/div&gt;`)[0];
#                 popup_c5f60941c3d8d13100cdb3f819d64857.setContent(html_eb802bb3630e9f1d1d50c2442c89e482);
#
#
#
#         marker_364d8c775bd5df7ae53b7d36669871a7.bindPopup(popup_c5f60941c3d8d13100cdb3f819d64857)
#         ;
#
#
#
#
#             var marker_670e060a7a44e9b9ac1e839286239fb6 = L.marker(
#                 [30.275891625377785, -97.74735387960183],
#                 {}
#             ).addTo(map_ecb00038b8e5a33f9e2c45a2e74b189f);
#
#
#             var icon_40a7aa1d441fa5cfaef8d5c5637e3651 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_670e060a7a44e9b9ac1e839286239fb6.setIcon(icon_40a7aa1d441fa5cfaef8d5c5637e3651);
#
#
#         var popup_c017b645a4c745c16b048e3518023d89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5764ba3c3dda277fd02c7f601e097114 = $(`&lt;div id=&quot;html_5764ba3c3dda277fd02c7f601e097114&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;700 W 12th St, Austin, Texas, 78701&lt;/div&gt;`)[0];
#                 popup_c017b645a4c745c16b048e3518023d89.setContent(html_5764ba3c3dda277fd02c7f601e097114);
#
#
#
#         marker_670e060a7a44e9b9ac1e839286239fb6.bindPopup(popup_c017b645a4c745c16b048e3518023d89)
#         ;
#
#
#
#
#             var marker_951db05a4c858ad8afd4110a22c95c24 = L.marker(
#                 [30.27646, -97.74822],
#                 {}
#             ).addTo(map_ecb00038b8e5a33f9e2c45a2e74b189f);
#
#
#             var icon_2b4ac6bafd288b59dc495a9c747aa63e = L.Awesom

# %%
bike_df.to_csv('bike_station_cleaned.csv')
